# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\mhg95\AppData\Local\Programs\Python\Python311\python.exe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

countrywise = pd.read_csv("../data/country_wise_latest.csv")

temp_data = countrywise.iloc[:,[8,9,14]].groupby("WHO Region").agg(np.mean)
fig, ax1 = plt.subplots(figsize=(12,6))

sns.barplot(x = temp_data.index.to_list(), y=temp_data.iloc[:,1].to_list(), color = "crimson", alpha=0.5, ax=ax1,label="Recovered/100 cases")
sns.barplot(x = temp_data.index.to_list(), y=temp_data.iloc[:,0].to_list(), color = "black", alpha=0.5, ax=ax1,label="Death/100 cases")
plt.legend()

plt.title("Death and Recovered Statistics per 100 Cases",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Death and Recovered Statistics per 100 Cases')

# %%
data = pd.read_csv("../data/contrywise_economicdata.csv")

# %%
sns.set_theme(style="whitegrid")

fig, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(fig, left=True, bottom=True)
sns.scatterplot(x="Deaths / 100 Cases",y="Recovered / 100 Cases",hue="WHO Region",data=data,
                sizes=(1, 8), linewidth=0, ax=ax)
# Out:
# <Axes: xlabel='Deaths / 100 Cases', ylabel='Recovered / 100 Cases'>

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'GDP', 'GDPchange', 'GDPperCapita',
#        'Inflation', 'Import', 'Export', 'Population', 'Country/Region',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases', 'New deaths',
#        'New recovered', 'Deaths / 100 Cases', 'Recovered / 100 Cases',
#        'Deaths / 100 Recovered', 'Confirmed last week', '1 week change',
#        '1 week % increase', 'WHO Region'],
#       dtype='object')

# %%
plot_data = data.loc[:,["New cases","Population", 'GDP',"WHO Region"]]
pairplot = sns.pairplot(plot_data,hue = "WHO Region")
logind = [0,1,2]
for i,j in zip(logind,logind):
    pairplot.axes[i,j].set_xscale("log")
    pairplot.axes[i,j].set_yscale("log")
# Out:
# c:\Users\mhg95\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plot_data = data.loc[:,["Import","Export","GDPperCapita","WHO Region"]]
pairplot = sns.pairplot(plot_data,hue = "WHO Region")
logind = [0,1,2]
for i,j in zip(logind,logind):
    pairplot.axes[i,j].set_xscale("log")
    pairplot.axes[i,j].set_yscale("log")
# Out:
# c:\Users\mhg95\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
